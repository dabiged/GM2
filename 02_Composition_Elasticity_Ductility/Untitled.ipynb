# %% [markdown]
# Reading the ternary diagram. For each sample, determine the percentage of each of the 3
# unknown components A, B and C.

# %%
from IPython.display import Image
img = '/home/cdinneen/MOGE_and_Other_UniWork/Other_Online_Courses/Zoback_GeoMechanics_II/Assignments/02_Composition_Elasticity_Ductility/Figure1.png'
Image(filename=img)

# %%
Circle_A=0.38
Circle_B=0.56
Circle_C=0.06

Triangle_A=0.15
Triangle_B=0.20
Triangle_C=0.65

# %%
print(Circle_A+Circle_B+Circle_C)
print(Triangle_A+Triangle_B+Triangle_C)
# Out:
# 1.0
# 1.0
