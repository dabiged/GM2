# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_fwf("GP208_HW1_Barnett_Density_Log.txt",sep="\t")

# %%
data.columns=["depth", "rho"]

# %%
data
# Out:
#                 depth  rho
# 0          95\t1.8778  NaN
# 1        95.5\t1.8778  NaN
# 2          96\t1.8778  NaN
# 3        96.5\t1.8778  NaN
# 4          97\t1.8778  NaN
# 5        97.5\t1.8778  NaN
# 6          98\t1.8778  NaN
# 7        98.5\t1.8778  NaN
# 8          99\t1.8778  NaN
# 9        99.5\t1.8778  NaN
# 10        100\t1.8778  NaN
# 11      100.5\t1.8778  NaN
# 12        101\t1.8709  NaN
# 13      101.5\t1.8317  NaN
# 14        102\t1.8363  NaN
# 15        102.5\t1.85  NaN
# 16        103\t1.8441  NaN
# 17      103.5\t1.8299  NaN
# 18        104\t1.8303  NaN
# 19      104.5\t1.8555  NaN
# 20        105\t1.8603  NaN
# 21      105.5\t1.8491  NaN
# 22        106\t1.8387  NaN
# 23      106.5\t1.8514  NaN
# 24        107\t1.8729  NaN
# 25      107.5\t1.8746  NaN
# 26        108\t1.8667  NaN
# 27      108.5\t1.8845  NaN
# 28        109\t1.8826  NaN
# 29      109.5\t1.8585  NaN
# ...               ...  ...
# 12168    6179\t2.0899  NaN
# 12169  6179.5\t2.0869  NaN
# ...
